# %% [markdown]
# # Caching Athena with DynamoDB

# %%
import json
import boto3
import hashlib
import time
import zlib
import pandas as pd

# Initialize Athena Client
AWS_REGION = "us-east-2"  # Change to your region
athena = boto3.client("athena", region_name=AWS_REGION)
ATHENA_DATABASE = "chalk"
ATHENA_TABLE = "chalkjuice_data"
ATHENA_OUTPUT_BUCKET = "s3://chalkjuice/golden_athena/"  # Replace with your actual S3 bucket

# Initialize Dynamo Client
dynamodb = boto3.client("dynamodb")
DYNAMODB_TABLE = "gold_hash"

# %% [markdown]
# ## Definitions

# %%
def run_athena_query(query):
    """Execute an Athena query and fetch results."""
    query_execution = athena.start_query_execution(
        QueryString=query,
        QueryExecutionContext={"Database": ATHENA_DATABASE},
        ResultConfiguration={"OutputLocation": ATHENA_OUTPUT_BUCKET}
    )
    query_execution_id = query_execution["QueryExecutionId"]


        # Wait for Query to Complete
    while True:
        status = athena.get_query_execution(QueryExecutionId=query_execution_id)
        state = status["QueryExecution"]["Status"]["State"]
        print(state)
        
        if state in ["SUCCEEDED", "FAILED", "CANCELLED"]:
            break
        
        time.sleep(.1)  # Check every .1 seconds

    if state != "SUCCEEDED":
        raise Exception(f"Athena query failed with state: {state}")
    
    # Get Query Results
    results = athena.get_query_results(QueryExecutionId=query_execution_id)

    columns = [col["Label"] for col in results["ResultSet"]["ResultSetMetadata"]["ColumnInfo"]]

    # Extract Rows
    rows = []
    for row in results["ResultSet"]["Rows"][1:]:  # Skip header row
        extracted_row = [col.get("VarCharValue", None) for col in row["Data"]]  # Extract actual values
        rows.append(extracted_row)

    df = pd.DataFrame(rows, columns=columns)
    df = df.fillna("NA")
    df.columns = df.columns.str.replace('_', ' ').str.title()
    
    
    df['Date'] = pd.to_datetime(df['Date'])  # Convert date column to datetime

    df = df.sort_values(by=['Season', 'Date'], ascending=[False, True])

    df['Date'] = df['Date'].astype(str)  # Convert the Date column to string

    
    return df

def hash_query(query):
    """Generate a SHA256 hash for the given query."""
    return hashlib.sha256(query.encode()).hexdigest()

def compress_json(df):
    # Convert DataFrame to JSON format
    json_str = df.to_json(orient="records")
    
    # Compress the JSON string
    compressed_data = zlib.compress(json_str.encode())

    return compressed_data

def decompress_json(compressed_data):
    """Decompress JSON data from zlib."""
    return json.loads(zlib.decompress(compressed_data).decode())

def store_in_cache(query_hash, compressed_json):
    """Store the compressed query result in DynamoDB."""
    dynamodb.put_item(
        TableName=DYNAMODB_TABLE,
        Item={
            "query_hash": {"S": query_hash},
            "compressed_json": {"B": compressed_json} # Compressed JSON stored as binary
        }
    )

# %% [markdown]
# ## Manually cache athena queries

# %%
for year in range(1967, 2024):
    query = f'''SELECT * FROM chalkjuice_data WHERE season = {year};'''
    print(query)

    query_hash = hash_query(query)

    result_df = run_athena_query(query)

    compressed_json = compress_json(result_df)

    store_in_cache(query_hash, compressed_json)
# Out:
# SELECT * FROM chalkjuice_data WHERE season = 1967;
# QUEUED
# QUEUED
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# SUCCEEDED
# 0
# SELECT * FROM chalkjuice_data WHERE season = 1968;
# QUEUED
# QUEUED
# RUNNING
# RUNNING
# SUCCEEDED
# 1
# SELECT * FROM chalkjuice_data WHERE season = 1969;
# QUEUED
# QUEUED
# RUNNING
# RUNNING
# RUNNING
# SUCCEEDED
# 2
# SELECT * FROM chalkjuice_data WHERE season = 1970;
# QUEUED
# QUEUED
# QUEUED
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# SUCCEEDED
# 3
# SELECT * FROM chalkjuice_data WHERE season = 1971;
# QUEUED
# QUEUED
# RUNNING
# RUNNING
# SUCCEEDED
# 4
# SELECT * FROM chalkjuice_data WHERE season = 1972;
# QUEUED
# RUNNING
# SUCCEEDED
# 5
# SELECT * FROM chalkjuice_data WHERE season = 1973;
# QUEUED
# QUEUED
# RUNNING
# RUNNING
# SUCCEEDED
# 6
# SELECT * FROM chalkjuice_data WHERE season = 1974;
# QUEUED
# QUEUED
# RUNNING
# RUNNING
# SUCCEEDED
# 7
# SELECT * FROM chalkjuice_data WHERE season = 1975;
# QUEUED
# QUEUED
# RUNNING
# RUNNING
# SUCCEEDED
# 8
# SELECT * FROM chalkjuice_data WHERE season = 1976;
# QUEUED
# QUEUED
# RUNNING
# RUNNING
# RUNNING
# SUCCEEDED
# 9
# SELECT * FROM chalkjuice_data WHERE season = 1977;
# QUEUED
# QUEUED
# RUNNING
# RUNNING
# SUCCEEDED
# 10
# SELECT * FROM chalkjuice_data WHERE season = 1978;
# QUEUED
# QUEUED
# RUNNING
# RUNNING
# SUCCEEDED
# 11
# SELECT * FROM chalkjuice_data WHERE season = 1979;
# QUEUED
# QUEUED
# RUNNING
# RUNNING
# SUCCEEDED
# 12
# SELECT * FROM chalkjuice_data WHERE season = 1980;
# QUEUED
# QUEUED
# RUNNING
# RUNNING
# SUCCEEDED
# 13
# SELECT * FROM chalkjuice_data WHERE season = 1981;
# QUEUED
# QUEUED
# RUNNING
# RUNNING
# SUCCEEDED
# 14
# SELECT * FROM chalkjuice_data WHERE season = 1982;
# QUEUED
# QUEUED
# RUNNING
# RUNNING
# SUCCEEDED
# 15
# SELECT * FROM chalkjuice_data WHERE season = 1983;
# QUEUED
# QUEUED
# RUNNING
# RUNNING
# SUCCEEDED
# 16
# SELECT * FROM chalkjuice_data WHERE season = 1984;
# QUEUED
# QUEUED
# RUNNING
# RUNNING
# SUCCEEDED
# 17
# SELECT * FROM chalkjuice_data WHERE season = 1985;
# QUEUED
# QUEUED
# RUNNING
# RUNNING
# SUCCEEDED
# 18
# SELECT * FROM chalkjuice_data WHERE season = 1986;
# QUEUED
# QUEUED
# RUNNING
# RUNNING
# SUCCEEDED
# 19
# SELECT * FROM chalkjuice_data WHERE season = 1987;
# QUEUED
# QUEUED
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# SUCCEEDED
# 20
# SELECT * FROM chalkjuice_data WHERE season = 1988;
# QUEUED
# QUEUED
# RUNNING
# RUNNING
# RUNNING
# SUCCEEDED
# 21
# SELECT * FROM chalkjuice_data WHERE season = 1989;
# QUEUED
# QUEUED
# RUNNING
# RUNNING
# SUCCEEDED
# 22
# SELECT * FROM chalkjuice_data WHERE season = 1990;
# QUEUED
# QUEUED
# QUEUED
# RUNNING
# RUNNING
# RUNNING
# SUCCEEDED
# 23
# SELECT * FROM chalkjuice_data WHERE season = 1991;
# QUEUED
# QUEUED
# RUNNING
# RUNNING
# SUCCEEDED
# 24
# SELECT * FROM chalkjuice_data WHERE season = 1992;
# QUEUED
# QUEUED
# RUNNING
# RUNNING
# RUNNING
# SUCCEEDED
# 25
# SELECT * FROM chalkjuice_data WHERE season = 1993;
# QUEUED
# QUEUED
# RUNNING
# RUNNING
# RUNNING
# SUCCEEDED
# 26
# SELECT * FROM chalkjuice_data WHERE season = 1994;
# QUEUED
# QUEUED
# RUNNING
# RUNNING
# RUNNING
# SUCCEEDED
# 27
# SELECT * FROM chalkjuice_data WHERE season = 1995;
# QUEUED
# QUEUED
# RUNNING
# RUNNING
# SUCCEEDED
# 28
# SELECT * FROM chalkjuice_data WHERE season = 1996;
# QUEUED
# RUNNING
# RUNNING
# RUNNING
# SUCCEEDED
# 29
# SELECT * FROM chalkjuice_data WHERE season = 1997;
# QUEUED
# QUEUED
# RUNNING
# RUNNING
# SUCCEEDED
# 30
# SELECT * FROM chalkjuice_data WHERE season = 1998;
# QUEUED
# QUEUED
# RUNNING
# RUNNING
# RUNNING
# SUCCEEDED
# 31
# SELECT * FROM chalkjuice_data WHERE season = 1999;
# QUEUED
# QUEUED
# RUNNING
# RUNNING
# RUNNING
# SUCCEEDED
# 32
# SELECT * FROM chalkjuice_data WHERE season = 2000;
# QUEUED
# QUEUED
# RUNNING
# RUNNING
# SUCCEEDED
# 33
# SELECT * FROM chalkjuice_data WHERE season = 2001;
# QUEUED
# QUEUED
# RUNNING
# RUNNING
# SUCCEEDED
# 34
# SELECT * FROM chalkjuice_data WHERE season = 2002;
# QUEUED
# RUNNING
# RUNNING
# RUNNING
# SUCCEEDED
# 35
# SELECT * FROM chalkjuice_data WHERE season = 2003;
# QUEUED
# QUEUED
# RUNNING
# RUNNING
# SUCCEEDED
# 36
# SELECT * FROM chalkjuice_data WHERE season = 2004;
# QUEUED
# QUEUED
# RUNNING
# RUNNING
# SUCCEEDED
# 37
# SELECT * FROM chalkjuice_data WHERE season = 2005;
# QUEUED
# QUEUED
# RUNNING
# RUNNING
# RUNNING
# SUCCEEDED
# 38
# SELECT * FROM chalkjuice_data WHERE season = 2006;
# QUEUED
# QUEUED
# RUNNING
# RUNNING
# SUCCEEDED
# 39
# SELECT * FROM chalkjuice_data WHERE season = 2007;
# QUEUED
# QUEUED
# RUNNING
# RUNNING
# RUNNING
# SUCCEEDED
# 40
# SELECT * FROM chalkjuice_data WHERE season = 2008;
# QUEUED
# QUEUED
# RUNNING
# RUNNING
# RUNNING
# SUCCEEDED
# 41
# SELECT * FROM chalkjuice_data WHERE season = 2009;
# QUEUED
# QUEUED
# RUNNING
# RUNNING
# SUCCEEDED
# 42
# SELECT * FROM chalkjuice_data WHERE season = 2010;
# QUEUED
# QUEUED
# RUNNING
# RUNNING
# SUCCEEDED
# 43
# SELECT * FROM chalkjuice_data WHERE season = 2011;
# QUEUED
# QUEUED
# RUNNING
# RUNNING
# SUCCEEDED
# 44
# SELECT * FROM chalkjuice_data WHERE season = 2012;
# QUEUED
# QUEUED
# RUNNING
# RUNNING
# SUCCEEDED
# 45
# SELECT * FROM chalkjuice_data WHERE season = 2013;
# QUEUED
# QUEUED
# RUNNING
# RUNNING
# SUCCEEDED
# 46
# SELECT * FROM chalkjuice_data WHERE season = 2014;
# QUEUED
# RUNNING
# RUNNING
# SUCCEEDED
# 47
# SELECT * FROM chalkjuice_data WHERE season = 2015;
# QUEUED
# QUEUED
# RUNNING
# RUNNING
# RUNNING
# SUCCEEDED
# 48
# SELECT * FROM chalkjuice_data WHERE season = 2016;
# QUEUED
# QUEUED
# RUNNING
# RUNNING
# SUCCEEDED
# 49
# SELECT * FROM chalkjuice_data WHERE season = 2017;
# QUEUED
# QUEUED
# QUEUED
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# SUCCEEDED
# 50
# SELECT * FROM chalkjuice_data WHERE season = 2018;
# QUEUED
# QUEUED
# RUNNING
# RUNNING
# SUCCEEDED
# 51
# SELECT * FROM chalkjuice_data WHERE season = 2019;
# QUEUED
# QUEUED
# RUNNING
# RUNNING
# SUCCEEDED
# 52
# SELECT * FROM chalkjuice_data WHERE season = 2020;
# QUEUED
# QUEUED
# RUNNING
# RUNNING
# RUNNING
# SUCCEEDED
# 53
# SELECT * FROM chalkjuice_data WHERE season = 2021;
# QUEUED
# QUEUED
# RUNNING
# RUNNING
# SUCCEEDED
# 54
# SELECT * FROM chalkjuice_data WHERE season = 2022;
# QUEUED
# QUEUED
# RUNNING
# RUNNING
# SUCCEEDED
# 55
# SELECT * FROM chalkjuice_data WHERE season = 2023;
# QUEUED
# QUEUED
# RUNNING
# RUNNING
# SUCCEEDED
# 56

# %% [markdown]
# ## Manually pull cached data into pandas or just verify its there

# %%
def get_cached_result(query: str) -> pd.DataFrame:
    """
    Check if the query hash exists in DynamoDB.
    If it exists, retrieve and decompress the JSON data, then return as a Pandas DataFrame.
    """
    # Create hash from the query
    query_hash = hash_query(query)
    #print(query_hash)

    # Check if the hash exists in DynamoDB
    response = dynamodb.get_item(
        TableName=DYNAMODB_TABLE,
        Key={"query_hash": {"S": query_hash}}
    )


    # If hash exists, retrieve and decompress the data
    if "Item" in response:
        print("Item was cached.")
        compressed_json = response["Item"]["compressed_json"]["B"]  # Get binary data

        # Decompress and convert back to JSON
        json_str = zlib.decompress(compressed_json).decode()
        data = json.loads(json_str)

        # Convert JSON to Pandas DataFrame
        return pd.DataFrame(data)
    
    else:
        print("Query not cached.")
        print(query)
        return None

# %%
for year in range(1967, 2024):
    query = f'''SELECT * FROM chalkjuice_data WHERE season = {year};'''
    df = get_cached_result(query)

df.head(10)
# Out:
# Item was cached.
# Item was cached.
# Item was cached.
# Item was cached.
# Item was cached.
# Item was cached.
# Item was cached.
# Item was cached.
# Item was cached.
# Item was cached.
# Item was cached.
# Item was cached.
# Item was cached.
# Item was cached.
# Item was cached.
# Item was cached.
# Item was cached.
# Item was cached.
# Item was cached.
# Item was cached.
# Item was cached.
# Item was cached.
# Item was cached.
# Item was cached.
# Item was cached.
# Item was cached.
# Item was cached.
# Item was cached.
# Item was cached.
# Item was cached.
# Item was cached.
# Item was cached.
# Item was cached.
# Item was cached.
# Item was cached.
# Item was cached.
# Item was cached.
# Item was cached.
# Item was cached.
# Item was cached.
# Item was cached.
# Item was cached.
# Item was cached.
# Item was cached.
# Item was cached.
# Item was cached.
# Item was cached.
# Item was cached.
# Item was cached.
# Item was cached.
# Item was cached.
# Item was cached.
# Item was cached.
# Item was cached.
# Item was cached.
# Item was cached.
# Item was cached.
#          Date Week Team Opponent Result Points Points Allowed Overtime  \
# 0  2023-09-07    1  DET      KAN      W     21             20        0
# 1  2023-09-07    1  KAN      DET      L     20             21        0
# 2  2023-09-10    1  ARI      WAS      L     16             20        0
# 3  2023-09-10    1  ATL      CAR      W     24             10        0
# 4  2023-09-10    1  BAL      HOU      W     25              9        0
# 5  2023-09-10    1  CAR      ATL      L     10             24        0
# 6  2023-09-10    1  CHI      GNB      L     20             38        0
# 7  2023-09-10    1  CIN      CLE      L      3             24        0
# 8  2023-09-10    1  CLE      CIN      W     24              3        0
# 9  2023-09-10    1  DAL      NYG      W     40              0        0
#
#   Home Game Passing Com  ... Tds Pr Tds Blocked Fg Tds Blocked Punt  \
# 0         1          22  ...      0              0                0
# 1         0          21  ...      0              0                0
# 2         1          21  ...      0              0                0
# 3         0          15  ...      0              0                0
# 4         0          17  ...      0              0                0
# 5         1          20  ...      0              0                0
# 6         0          24  ...      0              0                0
# 7         1          14  ...      0              0                0
# 8         0          16  ...      0              0                0
# 9         1          13  ...      0              1                0
#
#   Tds Walkoff Tds Other 1D Passes 1D Runs   Weekday Game Duration Minutes  \
# 0           0         0        11       8  Thursday                   182
# 1           0         0        10       6  Thursday                   182
# 2           0         0         9       4    Sunday                   188
# 3           0         0         6       7    Sunday                   186
# 4           0         0         8       7    Sunday                   196
# 5           0         0         9       9    Sunday                   186
# 6           0         0        12       8    Sunday                   190
# 7           0         0         3       2    Sunday                   183
# 8           0         0         9      12    Sunday                   183
# 9           0         0         8       7    Sunday                   175
#
#   Season
# 0   2023
# 1   2023
# 2   2023
# 3   2023
# 4   2023
# 5   2023
# 6   2023
# 7   2023
# 8   2023
# 9   2023
#
# [10 rows x 51 columns]

# %% [markdown]
# ## Query from s3 using Athena. If the dataframe is cached pull from Dynamodb. If its not, query with athena and create a hash in dynamoDB

# %%
def get_df_try_hash(query):
    """
    Check if the query hash exists in DynamoDB.
    If it exists, retrieve and decompress the JSON data, then return as a Pandas DataFrame.
    """
    # Create hash from the query
    query_hash = hash_query(query)


    # Check if the hash exists in DynamoDB
    response = dynamodb.get_item(
        TableName=DYNAMODB_TABLE,
        Key={"query_hash": {"S": query_hash}}
    )


    # If hash exists, retrieve and decompress the data
    if "Item" in response:
        print("item was cached")
        compressed_json = response["Item"]["compressed_json"]["B"]  # Get binary data

        # Decompress and convert back to JSON
        json_str = zlib.decompress(compressed_json).decode()
        data = json.loads(json_str)

        # Convert JSON to Pandas DataFrame
        return pd.DataFrame(data)
    
    else:

        result_df = run_athena_query(query)

        compressed_json = compress_json(result_df)

        store_in_cache(query_hash, compressed_json)

        
        return df

# %%
# Example Usage
query = 'SELECT * FROM chalkjuice_data WHERE season = 1988;'
#query = "SELECT * FROM chalkjuice_data WHERE season = 2023;"
df = get_df_try_hash(query)
# Out:
# item was cached

# %%
df.head(10)
# Out:
#          Date Week Team Opponent Result Points Points Allowed Overtime  \
# 0  1988-09-04    1  ARI      CIN      L     14             21        0
# 1  1988-09-04    1  ATL      DET      L     17             31        0
# 2  1988-09-04    1  BAL      KAN      W      6              3        0
# 3  1988-09-04    1  BUF      MIN      W     13             10        0
# 4  1988-09-04    1  CHI      MIA      W     34              7        0
# 5  1988-09-04    1  CIN      ARI      W     21             14        0
# 6  1988-09-04    1  DAL      PIT      L     21             24        0
# 7  1988-09-04    1  DEN      SEA      L     14             21        0
# 8  1988-09-04    1  DET      ATL      W     31             17        0
# 9  1988-09-04    1  GNB      LAR      L      7             34        0
#
#   Home Game Passing Com  ... Tds Pr Tds Blocked Fg Tds Blocked Punt  \
# 0         1          21  ...      0              0                0
# 1         1          25  ...      0              0                0
# 2         1          21  ...      0              0                0
# 3         0          17  ...      0              0                0
# 4         0          14  ...      0              0                0
# 5         0          17  ...      0              0                0
# 6         1          24  ...      0              0                0
# 7         0          21  ...      0              0                0
# 8         0          13  ...      0              0                0
# 9         0          16  ...      0              0                0
#
#   Tds Walkoff Tds Other 1D Passes 1D Runs Weekday Game Duration Minutes Season
# 0           0         0        NA      NA  Sunday                    NA   1988
# 1           0         0        NA      NA  Sunday                    NA   1988
# 2           0         0        NA      NA  Sunday                    NA   1988
# 3           0         0        NA      NA  Sunday                    NA   1988
# 4           0         0        NA      NA  Sunday                    NA   1988
# 5           0         0        NA      NA  Sunday                    NA   1988
# 6           0         0        NA      NA  Sunday                    NA   1988
# 7           0         0        NA      NA  Sunday                    NA   1988
# 8           0         0        NA      NA  Sunday                    NA   1988
# 9           0         0        NA      NA  Sunday                    NA   1988
#
# [10 rows x 51 columns]
